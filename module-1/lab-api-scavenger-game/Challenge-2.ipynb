# %%
"""code dans le terminal"""
curl -u julie-grange:Token https://api.github.com/repos/mayadesp/ironhack-datalabs-dataparis0619-pt/commits?since=2019-05-10 >commit.json
# Out:
#   File "<ipython-input-23-f8b2ec4e54c9>", line 2
#     curl -u julie-grange:Token https://api.github.com/repos/mayadesp/ironhack-datalabs-dataparis0619-pt/commits?since=2019-05-10 >commit.json
#                 ^
# SyntaxError: invalid syntax

# %%
"""je récupère un fichier commit.json"""
# Out:
# 'je récupère un fichier commit.json'

# %%
import pandas as pd
import json
import requests
from pandas.io.json import json_normalize

# %%
data = pd.read_json('commit.json')
data.head()
# Out:
#                                               author  \
# 0  {'login': 'eye8', 'id': 1659798, 'node_id': 'M...
# 1  {'login': 'eye8', 'id': 1659798, 'node_id': 'M...
# 2  {'login': 'eye8', 'id': 1659798, 'node_id': 'M...
# 3  {'login': 'haggarw3', 'id': 22273533, 'node_id...
# 4  {'login': 'haggarw3', 'id': 22273533, 'node_id...
#
#                                         comments_url  \
# 0  https://api.github.com/repos/mayadesp/ironhack...
# 1  https://api.github.com/repos/mayadesp/ironhack...
# 2  https://api.github.com/repos/mayadesp/ironhack...
# 3  https://api.github.com/repos/mayadesp/ironhack...
# 4  https://api.github.com/repos/mayadesp/ironhack...
#
#                                               commit  \
# 0  {'author': {'name': 'Zhou Zhou', 'email': 'zho...
# 1  {'author': {'name': 'Zhou Zhou', 'email': 'zho...
# 2  {'author': {'name': 'Zhou Zhou', 'email': 'zho...
# 3  {'author': {'name': 'Himanshu Aggarwal', 'emai...
# ...

# %%
data = pd.DataFrame(data)
data.head()
# Out:
#                                               author  \
# 0  {'login': 'eye8', 'id': 1659798, 'node_id': 'M...
# 1  {'login': 'eye8', 'id': 1659798, 'node_id': 'M...
# 2  {'login': 'eye8', 'id': 1659798, 'node_id': 'M...
# 3  {'login': 'haggarw3', 'id': 22273533, 'node_id...
# 4  {'login': 'haggarw3', 'id': 22273533, 'node_id...
#
#                                         comments_url  \
# 0  https://api.github.com/repos/mayadesp/ironhack...
# 1  https://api.github.com/repos/mayadesp/ironhack...
# 2  https://api.github.com/repos/mayadesp/ironhack...
# 3  https://api.github.com/repos/mayadesp/ironhack...
# 4  https://api.github.com/repos/mayadesp/ironhack...
#
#                                               commit  \
# 0  {'author': {'name': 'Zhou Zhou', 'email': 'zho...
# 1  {'author': {'name': 'Zhou Zhou', 'email': 'zho...
# 2  {'author': {'name': 'Zhou Zhou', 'email': 'zho...
# 3  {'author': {'name': 'Himanshu Aggarwal', 'emai...
# ...

# %%
data.columns
# Out:
# Index(['author', 'comments_url', 'commit', 'committer', 'html_url', 'node_id',
#        'parents', 'sha', 'url'],
#       dtype='object')

# %%
def flatten(data, col_list):
    for column in col_list:
        flattened = pd.DataFrame(dict(data[column])).transpose()
        columns = [str(col) for col in flattened.columns]
        flattened.columns = [column + '_' + colname for colname in columns]
        data = pd.concat([data, flattened], axis=1)
        data = data.drop(column, axis=1)
    return data


nested_columns = ['author', 'commit']

flat = flatten(data, nested_columns)
flat.head()
# Out:
#                                         comments_url  \
# 0  https://api.github.com/repos/mayadesp/ironhack...
# 1  https://api.github.com/repos/mayadesp/ironhack...
# 2  https://api.github.com/repos/mayadesp/ironhack...
# 3  https://api.github.com/repos/mayadesp/ironhack...
# 4  https://api.github.com/repos/mayadesp/ironhack...
#
#                                            committer  \
# 0  {'login': 'eye8', 'id': 1659798, 'node_id': 'M...
# 1  {'login': 'eye8', 'id': 1659798, 'node_id': 'M...
# 2  {'login': 'web-flow', 'id': 19864447, 'node_id...
# 3  {'login': 'haggarw3', 'id': 22273533, 'node_id...
# 4  {'login': 'web-flow', 'id': 19864447, 'node_id...
#
#                                             html_url  \
# 0  https://github.com/mayadesp/ironhack-datalabs-...
# 1  https://github.com/mayadesp/ironhack-datalabs-...
# 2  https://github.com/mayadesp/ironhack-datalabs-...
# 3  https://github.com/mayadesp/ironhack-datalabs-...
# ...

# %%
data.columns
# Out:
# Index(['author', 'comments_url', 'commit', 'committer', 'html_url', 'node_id',
#        'parents', 'sha', 'url'],
#       dtype='object')

# %%
data['commit'].count()
# Out:
# 11
