# %% [markdown]
# # Before you start :
#    - These exercises are related to the Subsetting and Descriptive Stats lessons.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - All datasets are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# #### Import all the libraries that are necessary

# %%
# import libraries here
import pandas as pd

import matplotlib
# %matplotlib inline

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### In this challenge we will use the `Temp_States.csv` file.
#
# #### First import it into a data frame called `temp`.

# %%
# your answer here
temp = pd.read_csv('Temp_States.csv', sep = ',')

# %% [markdown]
# #### Print `temp`

# %%
print(temp)
# Out:
#          City        State  Temperature
# 0         NYC     New York    19.444444
# 1      Albany     New York     9.444444
# 2     Buffalo     New York     3.333333
# 3    Hartford  Connecticut    17.222222
# 4  Bridgeport  Connecticut    14.444444
# 5      Treton   New Jersey    22.222222
# 6      Newark   New Jersey    20.000000

# %% [markdown]
# #### Explore the data types of the Temp dataframe. What type of data do we have? Comment your result.

# %%
# your answer here
temp.info()

#les colonnes city et state sont des string (ou catégorie) et la colonne Température contient des float
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
# City           7 non-null object
# State          7 non-null object
# Temperature    7 non-null float64
# dtypes: float64(1), object(2)
# memory usage: 248.0+ bytes

# %% [markdown]
# #### Select the rows where state is New York

# %%
# your answer here
#temp.loc[0:6, 'State']
temp_new_york = temp[temp.State == 'New York']

# %% [markdown]
# #### What is the average of the temperature of cities in New York?

# %%
# your answer here
temp_new_york.mean()
# Out:
# Temperature    10.740741
# dtype: float64

# %% [markdown]
# #### We want to know cities and states with Temperature above 15 degress Celcius

# %%
# your answer here
temp[temp.Temperature >15 ]
# Out:
#        City        State  Temperature
# 0       NYC     New York    19.444444
# 3  Hartford  Connecticut    17.222222
# 5    Treton   New Jersey    22.222222
# 6    Newark   New Jersey    20.000000

# %% [markdown]
# #### Now, return only the cities that have a temperature above 15 degress Celcius

# %%
# your answer here

above_15 = temp[temp.Temperature >15 ]
above_15['City']
# Out:
# 0         NYC
# 3    Hartford
# 5      Treton
# 6      Newark
# Name: City, dtype: object

# %% [markdown]
# #### We want to know which cities have a temperature above 15 degrees Celcius and below 20 degrees Celcius
#
# *Hint: First write the condition then select the rows.*

# %%
# your answer here
temp[(temp.Temperature >15) & (temp.Temperature <20)]
# Out:
#        City        State  Temperature
# 0       NYC     New York    19.444444
# 3  Hartford  Connecticut    17.222222

# %% [markdown]
# #### Find the mean and the standard deviation of the temperature of each state.
#
# *Hint: Use functions from Data Manipulation lesson*

# %%
# your answer here
new_york = temp[temp.State == 'New York']
new_york.mean()
new_york.std()
# Out:
# Temperature    8.133404
# dtype: float64

# %%
connecticut = temp[temp.State == 'Connecticut']
connecticut.mean()
connecticut.std()
# Out:
# Temperature    1.964186
# dtype: float64

# %%
new_jersey = temp[temp.State == 'New Jersey']
new_jersey.mean()
new_jersey.std()
# Out:
# Temperature    1.571348
# dtype: float64

# %%
#temp.groupby('State').mean() or .std()

# %% [markdown]
# # Challenge 2

# %% [markdown]
# #### Load the `employee.csv` file into a DataFrame. Call the dataframe `employee`

# %%
# your answer here

employee = pd.read_csv('Employee.csv', sep=',')
print(employee)
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 0    Jose         IT  Bachelor      M    analyst      1      35
# 1   Maria         IT    Master      F    analyst      2      30
# 2   David         HR    Master      M    analyst      2      30
# 3   Sonia         HR  Bachelor      F    analyst      4      35
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 6  Carlos         IT    Master      M         VP      8      70
# 7   Pedro         IT       Phd      M  associate      7      60
# 8     Ana         HR    Master      F         VP      8      70

# %% [markdown]
# #### Explore the data types of the Temp dataframe. Comment your results

# %%
# your answer here
employee.info()

#les colonnes Name, Department, Education, Gender et Title sont des catégories, Years et Salary sont des colonnes integer
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 7 columns):
# Name          9 non-null object
# Department    9 non-null object
# Education     9 non-null object
# Gender        9 non-null object
# Title         9 non-null object
# Years         9 non-null int64
# Salary        9 non-null int64
# dtypes: int64(2), object(5)
# memory usage: 584.0+ bytes

# %% [markdown]
# #### Show visually the frequency distribution (histogram) of the employee dataset. In few words describe these histograms?

# %%
# your answer here
employee.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11943d780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x119458908>]],
#       dtype=object)

# %% [markdown]
# #### What's the average salary in this company?

# %%
# your answer here
employee.Salary.mean()
# Out:
# 48.888888888888886

# %% [markdown]
# #### What's the highest salary?

# %%
# your answer here
employee.Salary.max()
# Out:
# 70

# %% [markdown]
# #### What's the lowest salary?

# %%
# your answer here
employee.Salary.min()
# Out:
# 30

# %% [markdown]
# #### Who are the employees with the lowest salary?

# %%
# your answer here
employee[employee.Salary == employee.Salary.min()]['Name']
# Out:
# 1    Maria
# 2    David
# Name: Name, dtype: object

# %% [markdown]
# #### Could you give all the information about an employee called David?

# %%
# your answer here
employee[employee.Name == 'David']
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Could you give only David's salary?

# %%
# your answer here
employee[employee.Name == 'David']['Salary']
# Out:
# 2    30
# Name: Salary, dtype: int64

# %% [markdown]
# #### Print all the rows where job title is associate

# %%
# your answer here

employee[employee.Title == "associate"]
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 7   Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Print the first 3 rows of your dataframe
#
# ##### Tip : There are 2 ways to do it. Do it both ways

# %%
# your answer here- 1 method
employee.head(3)
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %%
# your answer here- 2nd method
employee.loc[0:2]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Find the employees who's title is associate and the salary above 55?

# %%
# your answer here
employee[(employee.Title == 'associate') & (employee.Salary >55)]['Name']
# Out:
# 7    Pedro
# Name: Name, dtype: object

# %% [markdown]
# #### Group the employees based on their number of years of employment. What are the average salaries in each group?

# %%
# your answer here
employee.groupby('Years').mean()
# Out:
#           Salary
# Years
# 1      35.000000
# 2      38.333333
# 3      55.000000
# 4      35.000000
# 7      60.000000
# 8      70.000000

# %% [markdown]
# ####  What is the average Salary per title?

# %%
# your answer here

employee.groupby('Title').mean()['Salary']
# Out:
# Title
# VP           70.000000
# analyst      32.500000
# associate    56.666667
# Name: Salary, dtype: float64

# %% [markdown]
# #### Show a visual summary of the data using boxplot. What Are the First and Third Quartiles? Comment your results.
# ##### * Hint : Quantiles vs Quartiles*
# ##### - `In Probability and Statistics, quantiles are cut points dividing the range of a probability distribution into continuous intervals with equal probabilities. When division is into four parts the values of the variate corresponding to 25%, 50% and 75% of the total distribution are called quartiles.`

# %%
# draw boxplot here
employee.boxplot()

# %%
# print first quartile here
employee.quantile(0.25)
# Out:
# Years      2.0
# Salary    35.0
# Name: 0.25, dtype: float64

# %%
# print third quartile here
employee.quantile(0.75)
# Out:
# Years      7.0
# Salary    60.0
# Name: 0.75, dtype: float64

# %% [markdown]
# #### Is the mean salary per gender different?

# %%
# your answer here
employee.groupby('Gender').mean()
#employee.groupby('Gender').std()
# Out:
#         Years  Salary
# Gender
# F         4.0    47.5
# M         4.2    50.0

# %%
employee.Salary.std()
# Out:
# 16.541194367732675

# %% [markdown]
# #### Find the minimum, mean and the maximum of all numeric columns for each Department.
#
# ##### Hint: Use functions from Data Manipulation lesson

# %%
# your answer here
numeric = employee.Department.describe()
numeric
# Out:
# count      9
# unique     3
# top       IT
# freq       4
# Name: Department, dtype: object

# %%
employee.groupby('Department').mean()
# Out:
#               Name Education Gender      Title  Years  Salary
# Department
# HR             Ana  Bachelor      F         VP      2      30
# IT          Carlos  Bachelor      F         VP      1      30
# Sales          Eva  Bachelor      F  associate      2      55

# %%
employee.groupby('Department').min()['Years']
employee.groupby('Department').min()['Salary']
# Out:
# Department
# HR       30
# IT       30
# Sales    55
# Name: Salary, dtype: int64

# %%
employee.groupby('Department').max()['Years']
employee.groupby('Department').max()['Salary']
# Out:
# Department
# HR       70
# IT       70
# Sales    55
# Name: Salary, dtype: int64

# %% [markdown]
# ### Bonus Question
#
# #### For each department, compute the difference between the maximal salary and the minimal salary.
#
# ##### * Hint: try using `agg` or `apply` and `lambda`*

# %%
# your answer here

# %% [markdown]
# # Challenge 3

# %% [markdown]
# #### Open the Orders.csv dataset. Name your dataset orders

# %%
# your answer here
orders = pd.read_csv('Orders.zip', index_col=0)
orders.head()
# Out:
#    InvoiceNo StockCode  year  month  day  hour  \
# 0     536365    85123A  2010     12    3     8
# 1     536365     71053  2010     12    3     8
# 2     536365    84406B  2010     12    3     8
# 3     536365    84029G  2010     12    3     8
# 4     536365    84029E  2010     12    3     8
#
#                            Description  Quantity          InvoiceDate  \
# 0   white hanging heart t-light holder         6  2010-12-01 08:26:00
# 1                  white metal lantern         6  2010-12-01 08:26:00
# 2       cream cupid hearts coat hanger         8  2010-12-01 08:26:00
# 3  knitted union flag hot water bottle         6  2010-12-01 08:26:00
# 4       red woolly hottie white heart.         6  2010-12-01 08:26:00
#
#    UnitPrice  CustomerID         Country  amount_spent
# 0       2.55       17850  United Kingdom         15.30
# 1       3.39       17850  United Kingdom         20.34
# 2       2.75       17850  United Kingdom         22.00
# 3       3.39       17850  United Kingdom         20.34
# 4       3.39       17850  United Kingdom         20.34

# %% [markdown]
# #### Explore your dataset by looking at the data types and the summary statistics. Comment your results

# %%
# your answer here
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 397924 entries, 0 to 541908
# Data columns (total 13 columns):
# InvoiceNo       397924 non-null int64
# StockCode       397924 non-null object
# year            397924 non-null int64
# month           397924 non-null int64
# day             397924 non-null int64
# hour            397924 non-null int64
# Description     397924 non-null object
# Quantity        397924 non-null int64
# InvoiceDate     397924 non-null object
# UnitPrice       397924 non-null float64
# CustomerID      397924 non-null int64
# Country         397924 non-null object
# amount_spent    397924 non-null float64
# dtypes: float64(2), int64(7), object(4)
# memory usage: 42.5+ MB

# %%
# your answer here
orders.describe()
# Out:
#            InvoiceNo           year          month            day  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean   560617.126645    2010.934259       7.612537       3.614555
# std     13106.167695       0.247829       3.416527       1.928274
# min    536365.000000    2010.000000       1.000000       1.000000
# 25%    549234.000000    2011.000000       5.000000       2.000000
# 50%    561893.000000    2011.000000       8.000000       3.000000
# 75%    572090.000000    2011.000000      11.000000       5.000000
# max    581587.000000    2011.000000      12.000000       7.000000
#
#                 hour       Quantity      UnitPrice     CustomerID  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean       12.728247      13.021823       3.116174   15294.315171
# std         2.273535     180.420210      22.096788    1713.169877
# min         6.000000       1.000000       0.000000   12346.000000
# 25%        11.000000       2.000000       1.250000   13969.000000
# 50%        13.000000       6.000000       1.950000   15159.000000
# 75%        14.000000      12.000000       3.750000   16795.000000
# max        20.000000   80995.000000    8142.750000   18287.000000
#
#         amount_spent
# count  397924.000000
# mean       22.394749
# std       309.055588
# min         0.000000
# 25%         4.680000
# 50%        11.800000
# 75%        19.800000
# max    168469.600000

# %% [markdown]
# ####  What is the average Purchase Price?

# %%
# your answer here
orders.UnitPrice.mean()
# Out:
# 3.116174480549152

# %% [markdown]
# #### What were the highest and lowest purchase prices?

# %%
# your answer here
orders.UnitPrice.min()
# Out:
# 0.0

# %%
# your answer here
orders.UnitPrice.max()
# Out:
# 8142.75

# %% [markdown]
# #### Select all the customers we have in Spain

# %%
# your answer here
spain = orders[orders.Country == 'Spain']['CustomerID']
spain
# Out:
# 6421      12557
# 6422      12557
# 6423      12557
# 6424      12557
# 6425      12557
# 21565     17097
# 21566     17097
# 21567     17097
# 21568     17097
# 21569     17097
# 21570     17097
# 21571     17097
# 21572     17097
# 21573     17097
# 21574     17097
# 21575     17097
# 21576     17097
# 21577     17097
# 21578     17097
# 21579     17097
# 21580     17097
# 21581     17097
# 21582     17097
# 21583     17097
# 21584     17097
# 21585     17097
# 21586     17097
# 21587     17097
# 21588     17097
# 21589     17097
#           ...
# 535246    17097
# 535247    17097
# 535248    17097
# 535249    17097
# 535250    17097
# 535251    17097
# 535252    17097
# 535253    17097
# 535254    17097
# 535255    17097
# 535256    17097
# 535257    17097
# 535258    17097
# 535259    17097
# 535260    17097
# 535261    17097
# 535262    17097
# 535263    17097
# 535264    17097
# 535265    17097
# 535266    17097
# 535267    17097
# 535268    17097
# 535269    17097
# 535270    17097
# 535271    17097
# 535272    17097
# 535273    17097
# 535274    17097
# 535275    17097
# Name: CustomerID, Length: 2485, dtype: int64

# %% [markdown]
# #### How many customers do we have in Spain?
# ##### Hint : Use value_counts()

# %%
spain = orders[orders.Country == 'Spain']
customers = spain.groupby('CustomerID').count()
customers['InvoiceNo'].value_counts()
# Out:
# 8      2
# 33     2
# 22     2
# 62     1
# 211    1
# 5      1
# 10     1
# 12     1
# 206    1
# 15     1
# 273    1
# 19     1
# 21     1
# 23     1
# 346    1
# 58     1
# 27     1
# 478    1
# 69     1
# 147    1
# 45     1
# 48     1
# 50     1
# 52     1
# 57     1
# 121    1
# 4      1
# Name: InvoiceNo, dtype: int64

# %%
# your answer here
orders.Country.value_counts()
# Out:
# United Kingdom          354345
# Germany                   9042
# France                    8342
# EIRE                      7238
# Spain                     2485
# Netherlands               2363
# Belgium                   2031
# Switzerland               1842
# Portugal                  1462
# Australia                 1185
# Norway                    1072
# Italy                      758
# Channel Islands            748
# Finland                    685
# Cyprus                     614
# Sweden                     451
# Austria                    398
# Denmark                    380
# Poland                     330
# Japan                      321
# Israel                     248
# Unspecified                244
# Singapore                  222
# Iceland                    182
# USA                        179
# Canada                     151
# Greece                     145
# Malta                      112
# United Arab Emirates        68
# European Community          60
# RSA                         58
# Lebanon                     45
# Lithuania                   35
# Brazil                      32
# Czech Republic              25
# Bahrain                     17
# Saudi Arabia                 9
# Name: Country, dtype: int64

# %%
spain = orders[orders.Country == 'Spain']
spain['Country'].value_counts()
# Out:
# Spain    2485
# Name: Country, dtype: int64

# %% [markdown]
# #### Select all the customers who have bought more than 50 items ?

# %%
# your answer here
orders[orders.Quantity > 50]
items = orders[orders.Quantity > 50]['CustomerID']
set(items)
# Out:
# {16389,
#  16394,
#  16395,
#  16398,
#  16401,
#  16405,
#  16407,
#  16409,
#  16416,
#  16419,
#  16422,
#  16432,
#  16446,
#  16457,
#  16460,
#  16463,
#  16464,
#  16466,
#  16475,
#  16480,
#  16488,
#  16493,
#  16505,
#  16511,
#  16515,
#  16523,
#  16525,
#  16531,
#  16532,
#  16549,
#  16550,
#  16551,
#  16553,
#  16558,
#  16563,
#  16566,
#  16567,
#  16570,
#  16584,
#  16592,
#  16597,
#  16603,
#  16607,
#  16609,
#  16621,
#  16626,
#  16629,
#  16637,
#  16652,
#  16655,
#  16656,
#  16657,
#  16660,
#  16669,
#  16671,
#  16672,
#  16678,
#  16681,
#  16682,
#  16684,
#  16689,
#  16692,
#  16698,
#  16700,
#  16701,
#  16705,
#  16709,
#  16710,
#  16711,
#  16712,
#  16713,
#  13050,
#  13062,
#  13064,
#  13068,
#  13069,
#  13077,
#  13078,
#  13081,
#  13082,
#  13089,
#  13090,
#  13092,
#  13093,
#  13094,
#  13098,
#  13099,
#  13101,
#  13102,
#  13104,
#  13107,
#  13108,
#  13113,
#  13124,
#  13126,
#  13135,
#  13139,
#  13145,
#  13149,
#  13153,
#  13157,
#  13162,
#  13165,
#  13167,
#  13169,
#  13174,
#  13176,
#  13183,
#  13184,
#  13186,
#  13189,
#  13199,
#  13200,
#  13209,
#  13211,
#  13213,
#  13216,
#  13217,
#  13224,
#  13225,
#  13228,
#  13230,
#  13232,
#  13233,
#  13246,
#  13249,
#  13253,
#  13255,
#  13256,
#  13263,
#  13265,
#  13266,
#  13268,
#  13269,
#  13270,
#  13278,
#  13297,
#  13298,
#  13308,
#  13316,
#  13319,
#  13321,
#  13324,
#  13328,
#  13329,
#  13330,
#  13338,
#  13340,
#  13366,
#  13373,
#  13381,
#  13384,
#  13394,
#  13395,
#  13408,
#  13414,
#  13418,
#  13421,
#  13425,
#  13429,
#  13430,
#  13431,
#  13434,
#  13435,
#  13450,
#  13458,
#  13461,
#  13468,
#  13475,
#  13488,
#  13489,
#  13493,
#  13499,
#  13505,
#  13509,
#  13516,
#  13520,
#  13523,
#  13525,
#  13536,
#  13548,
#  13555,
#  13564,
#  13572,
#  13573,
#  13576,
#  13587,
#  13588,
#  13590,
#  13599,
#  13621,
#  13627,
#  13629,
#  13630,
#  13631,
#  13632,
#  13639,
#  13644,
#  13645,
#  13654,
#  13656,
#  13668,
#  13669,
#  13678,
#  13680,
#  13685,
#  13689,
#  13694,
#  13695,
#  13700,
#  13704,
#  13709,
#  13712,
#  13717,
#  13718,
#  13719,
#  13720,
#  13722,
#  13726,
#  13743,
#  13744,
#  13748,
#  13750,
#  13751,
#  13752,
#  13756,
#  13758,
#  13762,
#  13763,
#  13767,
#  13771,
#  13777,
#  13780,
#  13784,
#  13787,
#  13791,
#  13798,
#  13802,
#  13805,
#  13815,
#  13819,
#  13822,
#  13824,
#  13828,
#  13831,
#  13841,
#  13848,
#  13851,
#  13854,
#  13856,
#  13868,
#  13870,
#  13881,
#  13892,
#  13894,
#  13895,
#  13908,
#  13911,
#  13918,
#  13924,
#  13941,
#  13946,
#  13949,
#  13951,
#  13953,
#  13963,
#  13969,
#  13975,
#  13978,
#  13980,
#  13983,
#  13984,
#  13986,
#  13988,
#  13989,
#  14000,
#  14001,
#  14002,
#  14004,
#  14005,
#  14006,
#  14014,
#  14015,
#  14016,
#  14019,
#  14031,
#  14032,
#  14045,
#  14046,
#  14049,
#  14051,
#  14053,
#  14055,
#  14057,
#  14059,
#  14060,
#  14062,
#  14064,
#  14079,
#  14083,
#  14085,
#  14088,
#  14090,
#  14096,
#  14099,
#  14101,
#  14102,
#  14110,
#  14111,
#  14113,
#  14121,
#  14124,
#  14126,
#  14132,
#  14135,
#  14139,
#  14145,
#  14156,
#  14158,
#  14163,
#  14164,
#  14178,
#  14189,
#  14191,
#  14194,
#  14195,
#  14196,
#  14201,
#  14211,
#  14212,
#  14215,
#  14217,
#  14220,
#  14226,
#  14232,
#  14233,
#  14234,
#  14235,
#  14246,
#  14251,
#  14257,
#  14258,
#  14272,
#  14277,
#  14282,
#  14285,
#  14286,
#  14287,
#  14292,
#  14298,
#  14299,
#  14301,
#  14306,
#  14307,
#  14309,
#  14312,
#  14314,
#  14321,
#  14329,
#  14336,
#  14342,
#  14344,
#  14354,
#  14364,
#  14367,
#  14377,
#  14382,
#  14383,
#  14389,
#  14390,
#  14397,
#  14400,
#  14401,
#  14403,
#  14404,
#  14407,
#  14408,
#  14409,
#  14412,
#  14414,
#  14415,
#  14416,
#  14422,
#  14423,
#  14426,
#  14428,
#  14432,
#  14446,
#  14456,
#  14459,
#  14460,
#  14463,
#  14466,
#  14477,
#  14482,
#  14488,
#  14498,
#  14500,
#  14503,
#  14505,
#  14513,
#  14515,
#  14518,
#  14520,
#  14522,
#  14523,
#  14525,
#  14530,
#  14533,
#  14534,
#  14535,
#  14543,
#  14544,
#  14547,
#  14548,
#  14554,
#  14560,
#  14561,
#  14566,
#  14572,
#  14578,
#  14581,
#  14591,
#  14597,
#  14601,
#  14603,
#  14606,
#  14607,
#  14609,
#  14626,
#  14631,
#  14642,
#  14646,
#  14649,
#  14655,
#  14667,
#  14676,
#  14680,
#  14687,
#  14688,
#  14700,
#  14705,
#  14708,
#  14711,
#  14714,
#  14715,
#  14716,
#  14725,
#  14732,
#  14733,
#  14735,
#  14739,
#  14741,
#  14744,
#  14745,
#  14748,
#  14752,
#  14769,
#  14775,
#  14776,
#  14782,
#  14799,
#  14800,
#  14808,
#  14815,
#  14818,
#  14824,
#  14828,
#  14834,
#  14837,
#  14841,
#  14844,
#  14849,
#  14854,
#  14860,
#  14862,
#  14866,
#  14875,
#  14881,
#  14885,
#  14887,
#  14893,
#  14895,
#  14898,
#  14904,
#  14911,
#  ...}

# %% [markdown]
# #### Select orders from Spain that are above 50 items

# %%
# your answer here
orders[(orders.Quantity > 50)&(orders.Country == 'Spain')]
# Out:
#         InvoiceNo StockCode  year  month  day  hour  \
# 6421       536944     22383  2010     12    5    12
# 6422       536944     22384  2010     12    5    12
# 6423       536944     20727  2010     12    5    12
# 6424       536944     20725  2010     12    5    12
# 6425       536944     20728  2010     12    5    12
# 52416      540785    84997B  2011      1    2    11
# 52417      540785    84997D  2011      1    2    11
# 52418      540785    84997C  2011      1    2    11
# 52419      540785    84997A  2011      1    2    11
# 136767     547972     22383  2011      3    1    16
# 136768     547972     22384  2011      3    1    16
# 136771     547972     20728  2011      3    1    16
# 248797     558871     22384  2011      7    1    13
# 248798     558871     20727  2011      7    1    13
# 248799     558871     20725  2011      7    1    13
# 248800     558871     20728  2011      7    1    13
# 248801     558871    84997B  2011      7    1    13
# 248802     558871    84997D  2011      7    1    13
# 248803     558871    84997C  2011      7    1    13
# 248804     558871    84997A  2011      7    1    13
# 282906     561669     23295  2011      7    4    17
# 282907     561669     23297  2011      7    4    17
# 282908     561669     23294  2011      7    4    17
# 282909     561669     23296  2011      7    4    17
# 495742      childrens cutlery polkadot blue       288  2011-11-23 16:59:00
#
#         UnitPrice  CustomerID Country  amount_spent
# 6421         1.65       12557   Spain        115.50
# 6422         1.45       12557   Spain        145.00
# 6423         1.65       12557   Spain         99.00
# 6424         1.65       12557   Spain        115.50
# 6425         1.45       12557   Spain        145.00
# 52416        3.39       12557   Spain        488.16
# 52417        3.39       12557   Spain       1220.40
# 52418        3.39       12557   Spain       1220.40
# 52419        3.39       12557   Spain        488.16
# 136767       1.45       12557   Spain        217.50
# 136768       1.45       12557   Spain        217.50
# 136771       1.45       12557   Spain        217.50
# 248797       1.45       12557   Spain        145.00
# 248798       1.45       12557   Spain        145.00
# 248799       1.45       12557   Spain        145.00
# 248800       1.45       12557   Spain        145.00
# 248801       3.75       12557   Spain        270.00
# 248802       3.75       12557   Spain       1350.00
# 248803       3.75       12557   Spain       1350.00
# 248804       3.75       12557   Spain        270.00
# 282906       0.72       12507   Spain         92.16
# 282907       1.45       12507   Spain        208.80
# 282908       0.72       12507   Spain         92.16
# 282909       1.04       12507   Spain        133.12
# 282910       0.72       12507   Spain         92.16
# 315702       0.85       12484   Spain         51.00
# 355752       0.12       12546   Spain         11.52
# 398626       2.55       12454   Spain        183.60
# 398631       2.55       12454   Spain        183.60
# 398639       1.25       12454   Spain        250.00
# 398640       1.25       12454   Spain        360.00
# 407272       0.69       12596   Spain         66.24
# 426665       0.29       12597   Spain         20.88
# 426666       0.29       12597   Spain         20.88
# 426667       0.29       12597   Spain         20.88
# 495739       1.45       12557   Spain        290.00
# 495740       3.75       12557   Spain        270.00
# 495741       3.75       12557   Spain       1350.00
# 495742       3.75       12557   Spain       1080.00

# %% [markdown]
# #### Select all free orders

# %%
# your answer here
orders[orders.amount_spent == 0]
# Out:
#         InvoiceNo StockCode  year  month  day  hour  \
# 9302       537197     22841  2010     12    7    14
# 33576      539263     22580  2010     12    4    14
# 40089      539722     22423  2010     12    2    13
# 47068      540372     22090  2011      1    4    16
# 47070      540372     22553  2011      1    4    16
# 56674      541109     22168  2011      1    4    15
# 86789      543599    84535B  2011      2    4    13
# 130188     547417     22062  2011      3    3    10
# 139453     548318     22055  2011      3    3    12
# 145208     548871     22162  2011      4    1    14
# 157042     550188     22636  2011      4    4    18
# 187613     553000     47566  2011      5    4    15
# 198383     554037     22619  2011      5    5    14
# 279324     561284     22167  2011      7    2    12
# 282912     561669     22960  2011      7    4    17
# 285657     561916         M  2011      8    1    11
# 298054     562973     23157  2011      8    4    11
# 314745     564651     23270  2011      8    5    14
# 314746     564651     23268  2011      8    5    14
# 314747     564651     22955  2011      8    5    14
# 314748     564651     21786  2011      8    5    14
# 358655     568158      PADS  2011      9    7    12
# 361825     568384         M  2011      9    2     9
# 379913     569716     22778  2011     10    4     8
# 395529     571035         M  2011     10    4    12
# 420404     572893     21208  2011     10    3    14
# 436428     574138     23234  2011     11    4    11
# 436597     574175     22065  2011     11    4    11
# 436961     574252         M  2011     11    4    13
# 439361     574469     22385  2011     11    5    11
# 446125     574879     22625  2011     11    1    13
# 446793     574920     22899  2011     11    1    16
00
#
#         UnitPrice  CustomerID         Country  amount_spent
# 9302          0.0       12647         Germany           0.0
# 33576         0.0       16560  United Kingdom           0.0
# 40089         0.0       14911            EIRE           0.0
# 47068         0.0       13081  United Kingdom           0.0
# 47070         0.0       13081  United Kingdom           0.0
# 56674         0.0       15107  United Kingdom           0.0
# 86789         0.0       17560  United Kingdom           0.0
# 130188        0.0       13239  United Kingdom           0.0
# 139453        0.0       13113  United Kingdom           0.0
# 145208        0.0       14410  United Kingdom           0.0
# 157042        0.0       12457     Switzerland           0.0
# 187613        0.0       17667  United Kingdom           0.0
# 198383        0.0       12415       Australia           0.0
# 279324        0.0       16818  United Kingdom           0.0
# 282912        0.0       12507           Spain           0.0
# 285657        0.0       15581  United Kingdom           0.0
# 298054        0.0       14911            EIRE           0.0
# 314745        0.0       14646     Netherlands           0.0
# 314746        0.0       14646     Netherlands           0.0
# 314747        0.0       14646     Netherlands           0.0
# 314748        0.0       14646     Netherlands           0.0
# 358655        0.0       16133  United Kingdom           0.0
# 361825        0.0       12748  United Kingdom           0.0
# 379913        0.0       15804  United Kingdom           0.0
# 395529        0.0       12446             RSA           0.0
# 420404        0.0       18059  United Kingdom           0.0
# 436428        0.0       12415       Australia           0.0
# 436597        0.0       14110  United Kingdom           0.0
# 436961        0.0       12437          France           0.0
# 439361        0.0       12431       Australia           0.0
# 446125        0.0       13014  United Kingdom           0.0
# 446793        0.0       13985  United Kingdom           0.0
# 446794        0.0       13985  United Kingdom           0.0
# 454463        0.0       13081  United Kingdom           0.0
# 454464        0.0       13081  United Kingdom           0.0
# 479079        0.0       15602  United Kingdom           0.0
# 479546        0.0       12603         Germany           0.0
# 480649        0.0       12444          Norway           0.0
# 485985        0.0       16406  United Kingdom           0.0
# 502122        0.0       13256  United Kingdom           0.0

# %% [markdown]
# #### Select all orders that are 'lunch bag'
# #### Hint: Use string functions

# %%
# your answer here
orders[orders.Description.str.contains('lunch bag')]
# Out:
#         InvoiceNo StockCode  year  month  day  hour  \
# 93         536378     20725  2010     12    3     9
# 174        536385     22662  2010     12    3     9
# 363        536401     22662  2010     12    3    11
# 368        536401     20725  2010     12    3    11
# 369        536401     22382  2010     12    3    11
# 370        536401     20726  2010     12    3    11
# 371        536401     22384  2010     12    3    11
# 411        536404     22383  2010     12    3    11
# 412        536404     20728  2010     12    3    11
# 413        536404     20727  2010     12    3    11
# 541        536412     20728  2010     12    3    11
# 542        536412     22382  2010     12    3    11
# 544        536412     22662  2010     12    3    11
# 545        536412     22383  2010     12    3    11
# 546        536412     20727  2010     12    3    11
# 614        536412     20725  2010     12    3    11
# 1425       536542     22382  2010     12    3    14
# 1426       536542     20727  2010     12    3    14
# 1427       536542     22383  2010     12    3    14
# 2315       536576     20727  2010     12    3    16
# 2325       536577     20725  2010     12    3    16
# 2338       536579     20727  2010     12    3    16
# 3092       536597     22384  2010     12    3    17
# 3101       536597     20726  2010     12    3    17
# 3503       536634     20727  2010     12    4    11
# 3710       536643     22662  2010     12    4    11
# 3857       536698     22382  2010     12    4    12
# 4243       536754     22384  2010     12    4    14
# 4244       536754     20727  2010     12    4    14
# 4248       536754     22383  2010     12    4    14
# ...           ...       ...   ...    ...  ...   ...
# 538606     581412     20726  2011     12    4    14
# 538607     581412     20725  2011     12    4    14
# 538608     581412     23583  2011     12    4    14
# 538609     581412     20727  2011     12    4    14
# 538613     581412     23583  2011     12    4    14
# 538607       1.65       14415  United Kingdom          4.95
# 538608       1.65       14415  United Kingdom          4.95
# 538609       1.65       14415  United Kingdom          1.65
# 538613       1.65       14415  United Kingdom          3.30
# 538614       1.65       14415  United Kingdom          4.95
# 538714       1.65       16833  United Kingdom         16.50
# 538720       1.65       16833  United Kingdom         16.50
# 538722       1.65       16833  United Kingdom         16.50
# 538725       1.65       16833  United Kingdom         16.50
# 538836       1.65       17451  United Kingdom         16.50
# 538878       1.65       16358  United Kingdom         16.50
# 538879       1.65       16358  United Kingdom         16.50
# 538880       1.65       16358  United Kingdom         16.50
# 538881       1.65       16358  United Kingdom         16.50
# 538882       1.65       16358  United Kingdom         16.50
# 539028       1.65       17757  United Kingdom          1.65
# 539921       1.65       16794  United Kingdom          1.65
# 539922       1.65       16794  United Kingdom          3.30
# 539923       1.65       16794  United Kingdom          6.60
# 539957       1.65       17144  United Kingdom         16.50
# 539989       1.65       16401  United Kingdom         16.50
# 539998       1.65       16401  United Kingdom         16.50
# 540225       1.65       12748  United Kingdom          3.30
# 540268       1.65       12748  United Kingdom          1.65
# 540436       1.65       17001  United Kingdom         16.50
# 541695       1.65       14446  United Kingdom          1.65
# 541696       1.65       14446  United Kingdom          1.65
# 541862       1.65       17581  United Kingdom         16.50
# 541865       1.45       13777  United Kingdom         58.00
#
# [11556 rows x 13 columns]

# %% [markdown]
# #### Select all orders that are made in 2011 and are 'lunch bag'

# %%
# your answer here
orders[(orders.Description.str.contains('lunch bag')) & (orders.year == 2011)]
# Out:
#         InvoiceNo StockCode  year  month  day  hour  \
# 42678      540015     20725  2011      1    2    11
# 42679      540015     20726  2011      1    2    11
# 42851      540023     22382  2011      1    2    12
# 42852      540023     20726  2011      1    2    12
# 43616      540098     22384  2011      1    2    15
# 43617      540098     22383  2011      1    2    15
# 43618      540098     22382  2011      1    2    15
# 43619      540098     20727  2011      1    2    15
# 43620      540098     20727  2011      1    2    15
# 43658      540099     20725  2011      1    2    16
# 43659      540099     20726  2011      1    2    16
# 44179      540157     22384  2011      1    3    11
# 44329      540168     22383  2011      1    3    12
# 44448      540176     22382  2011      1    3    12
# 44449      540176     20725  2011      1    3    12
# 44937      540247     22383  2011      1    3    15
# 44968      540247     20728  2011      1    3    15
# 44970      540247     22382  2011      1    3    15
# 45557      540268     20725  2011      1    4    11
# 45593      540268     20726  2011      1    4    11
# 45594      540268     20728  2011      1    4    11
# 45595      540268     22384  2011      1    4    11
# 45646      540275     20728  2011      1    4    12
# 45651      540275     20726  2011      1    4    12
# 45652      540275     20727  2011      1    4    12
# 45664      540275     20725  2011      1    4    12
# 45681      540276     20728  2011      1    4    12
# 45682      540276     20727  2011      1    4    12
# 45683      540276     20726  2011      1    4    12
# 45684      540276     20725  2011      1    4    12
# ...           ...       ...   ...    ...  ...   ...
# 538606     581412     20726  2011     12    4    14
# 538607     581412     20725  2011     12    4    14
# 538608     581412     23583  2011     12    4    14
# 538609     581412     20727  2011     12    4    14
# 538613     581412     23583  2011     12    4    14
# 538614     581412     20727  2011     12    4    14
# 538607       1.65       14415  United Kingdom          4.95
# 538608       1.65       14415  United Kingdom          4.95
# 538609       1.65       14415  United Kingdom          1.65
# 538613       1.65       14415  United Kingdom          3.30
# 538614       1.65       14415  United Kingdom          4.95
# 538714       1.65       16833  United Kingdom         16.50
# 538720       1.65       16833  United Kingdom         16.50
# 538722       1.65       16833  United Kingdom         16.50
# 538725       1.65       16833  United Kingdom         16.50
# 538836       1.65       17451  United Kingdom         16.50
# 538878       1.65       16358  United Kingdom         16.50
# 538879       1.65       16358  United Kingdom         16.50
# 538880       1.65       16358  United Kingdom         16.50
# 538881       1.65       16358  United Kingdom         16.50
# 538882       1.65       16358  United Kingdom         16.50
# 539028       1.65       17757  United Kingdom          1.65
# 539921       1.65       16794  United Kingdom          1.65
# 539922       1.65       16794  United Kingdom          3.30
# 539923       1.65       16794  United Kingdom          6.60
# 539957       1.65       17144  United Kingdom         16.50
# 539989       1.65       16401  United Kingdom         16.50
# 539998       1.65       16401  United Kingdom         16.50
# 540225       1.65       12748  United Kingdom          3.30
# 540268       1.65       12748  United Kingdom          1.65
# 540436       1.65       17001  United Kingdom         16.50
# 541695       1.65       14446  United Kingdom          1.65
# 541696       1.65       14446  United Kingdom          1.65
# 541862       1.65       17581  United Kingdom         16.50
# 541865       1.45       13777  United Kingdom         58.00
#
# [11234 rows x 13 columns]

# %% [markdown]
# #### Show the frequency distribution of the amount spent in Spain.

# %%
# your answer here
spain = orders[orders.Country == 'Spain']
spain.hist(column = 'amount_spent')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11cf1a860>]],
#       dtype=object)

# %% [markdown]
# #### Select all orders made in the month of August

# %%
# your answer here
august = orders[orders.month == 8]

# %% [markdown]
# #### Select how many orders are made by countries in the month of August
# ##### Hint: Use value_counts()

# %%
# your answer here
august['Country'].value_counts()
# Out:
# United Kingdom     23105
# Germany              795
# EIRE                 593
# France               569
# Netherlands          280
# Switzerland          267
# Spain                252
# Belgium              194
# Israel               171
# Channel Islands      140
# Australia            107
# Italy                 95
# Austria               88
# Norway                77
# Finland               61
# Malta                 55
# Portugal              41
# Sweden                40
# Unspecified           23
# Iceland               22
# Poland                17
# Denmark               16
# Canada                 5
# Name: Country, dtype: int64

# %% [markdown]
# #### What's the  average amount of money spent by country

# %%
# your answer here
orders.groupby('Country').mean()['amount_spent']

#orders.amount_spent.groupby('Country').mean()
# Out:
# Country
# Australia               116.895620
# Austria                  25.624824
# Bahrain                  32.258824
# Belgium                  20.283772
# Brazil                   35.737500
# Canada                   24.280662
# Channel Islands          27.340160
# Cyprus                   22.134169
# Czech Republic           33.069600
# Denmark                  49.882474
# EIRE                     36.687745
# European Community       21.670833
# Finland                  32.913985
# France                   25.056827
# Germany                  25.311562
# Greece                   32.831172
# Iceland                  23.681319
# Israel                   29.119718
# Italy                    23.064960
# Japan                   116.561900
# Lebanon                  37.641778
# Lithuania                47.458857
# Malta                    24.335625
# Netherlands             120.798282
# Norway                   33.736418
# Poland                   22.226212
# Portugal                 22.872702
# RSA                      17.281207
# Saudi Arabia             16.213333
# Singapore                95.852658
# Spain                    24.779521
# Sweden                   85.096075
# Switzerland              30.642752
# USA                      20.002179
# United Arab Emirates     27.974706
# United Kingdom           20.625073
# Unspecified              10.930615
# Name: amount_spent, dtype: float64

# %% [markdown]
# #### What's the most expensive item?

# %%
# your answer here
orders.loc[orders['UnitPrice'].idxmax()]['Description']
# Out:
# 'postage'

# %% [markdown]
# #### What was the average amount spent per year ?

# %%
# your answer here
orders.groupby('year').mean()['amount_spent']
# Out:
# year
# 2010    21.892733
# 2011    22.430074
# Name: amount_spent, dtype: float64
