# %% [markdown]
# # Challenge 3

# %%
# import libraries here
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### Import the titanic file. Name your dataset `titanic`.

# %%
titanic = pd.read_csv('./titanic.csv',low_memory=False)
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes

# %%
#your code here
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
#
# *Hint: Use Pandas `select_dtypes`*

# %%
# your code here- numerical variable
numeric = titanic.select_dtypes(include=['int', 'float64'])
numeric.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0            1       0.0       3  22.0      1      0   7.2500
# 1            2       1.0       1  38.0      1      0  71.2833
# 2            3       1.0       3  26.0      0      0   7.9250
# 3            4       1.0       1  35.0      1      0  53.1000
# 4            5       0.0       3  35.0      0      0   8.0500

# %%
#your code here- categorical variable
categorical = titanic.select_dtypes(include=['object'])
categorical.head(5)
# Out:
#                                                 Name  Gender  \
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male
#
#              Ticket Cabin Embarked
# 0         A/5 21171    U0        S
# 1          PC 17599   C85        C
# 2  STON/O2. 3101282    U0        S
# 3            113803  C123        S
# 4            373450    U0        S

# %% [markdown]
# #### Set the plot style to `classic` and the figure size to `(12,6)`
#
# *Hint: To set the style you can use `matplotlib.pyplot` functions or seaborn*

# %%
# your code here
import matplotlib.style
import matplotlib as mpl
mpl.style.use('classic')
mpl.rcParams['figure.figsize'] = [12.0, 6.0]

# %% [markdown]
# #### Use the appropriate visulalization to show the distribution of the column `Age`

# %%
# your code here
x = titanic['Age']
plt.hist(x)
plt.title('Age')
# Out:
# Text(0.5, 1.0, 'Age')

# %% [markdown]
# #### Use subplots to plot the distribution of the `Age` variable with bins equal to `10`, `20` and `50`.

# %%
# your code here
fig, axes = plt.subplots(nrows=1, ncols=3)

x= titanic.Age

#plt.plot(x, 10)
axes[0].hist(x, 10)
axes[1].hist(x, 20)
axes[2].hist(x, 50)
# Out:
# (array([ 22.,  19.,  10.,  11.,  10.,  13.,   8.,   8.,  23.,  26.,  20.,
#          75.,  29.,  93., 109.,  43.,  72.,  68., 111.,  53.,  71.,  47.,
#          35.,  24.,  43.,  26.,  29.,  15.,  35.,  31.,  15.,  26.,   7.,
#          14.,  13.,   5.,   9.,   8.,  11.,   9.,   3.,   2.,   0.,   2.,
#           3.,   0.,   1.,   1.,   0.,   1.]),
#  array([ 0.17  ,  1.7666,  3.3632,  4.9598,  6.5564,  8.153 ,  9.7496,
#         11.3462, 12.9428, 14.5394, 16.136 , 17.7326, 19.3292, 20.9258,
#         22.5224, 24.119 , 25.7156, 27.3122, 28.9088, 30.5054, 32.102 ,
#         33.6986, 35.2952, 36.8918, 38.4884, 40.085 , 41.6816, 43.2782,
#         44.8748, 46.4714, 48.068 , 49.6646, 51.2612, 52.8578, 54.4544,
#         56.051 , 57.6476, 59.2442, 60.8408, 62.4374, 64.034 , 65.6306,
#         67.2272, 68.8238, 70.4204, 72.017 , 73.6136, 75.2102, 76.8068,
#         78.4034, 80.    ]),
#  <a list of 50 Patch objects>)

# %% [markdown]
# #### Whether the bin size affects your plot? Why?

# %%
#your comment here
oui, plus il va y avoir un bin grand plus la taille de la barre de l'histograme sera fin et donc aura un range d'age faible

# %% [markdown]
# #### Use seaborn to show the distribution of the column `Age`

# %%
# your code here
sns.distplot(x, kde=False, rug=True)

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Gender`. There are 2 ways of doing it. Do it both ways.
#
# *Hint: Use matplotlib and seaborn*

# %%
# your code here- 1st way
x = list(titanic['Gender'].value_counts('male'))
x

plt.pie(x, labels = ['Male', 'Female'])
# Out:
# ([<matplotlib.patches.Wedge at 0x1a229a0f60>,
# ...
#  [Text(-0.48083677220945115, 0.9893411941747885, 'Male'),
#   Text(0.48083667958064136, -0.9893412391939718, 'Female')])

# %%
# your code here- 2nd way
ax = sns.barplot(x=['Male', 'Female'], y=x)
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
# Out:
# [Text(0, 0, 'Male'), Text(0, 0, 'Female')]

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Pclass`

# %%
# your code here

x = dict(titanic['Pclass'].value_counts())

x=sorted(x.items(), key=lambda t: t[0])
x
valeur_Pclass = [a[1] for a in x]
labels_Pclass = [a[0] for a in x]

# %%
plt.pie(valeur_Pclass, labels = labels_Pclass)
# Out:
# ([<matplotlib.patches.Wedge at 0x1a22c2a748>,
# ...
#  [Text(0.7857105825523256, 0.7698434129518062, '1'),
#   Text(-0.6607894097998425, 0.8794073890389915, '2'),
#   Text(-0.14346972497658556, -1.0906037034666365, '3')])

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. Choose the appropriate plot to show below.

# %%
# your code here
ax = sns.boxplot(x='Age', data=titanic)
#ax.set_xticklabels(ax.get_xticklabels(),rotation=90)

# %% [markdown]
# #### What does the previous plot tell you about the feature `Age`? Comment.

# %%
# your comment here
l'age médian est d'environ 28 ans. La plupart des passagers ont entre 22 et 38 ans. Quelques passagers ont plus de 60 ans

# %% [markdown]
# #### Now in addition to the summary statistics, we also want to visualize the distribution of `Age`. Choose the appropriate plot to sow below.

# %%
#your code here
x = titanic['Age']
plt.hist(x)
plt.title('Age')
# Out:
# Text(0.5, 1.0, 'Age')

# %% [markdown]
# #### What additional information in the previous plot provide you about the feature `Age`? Comment.

# %%
#your comment here
la distribution semble suivre une loi normale

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the appropriate plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
#
# *Hint: One of the ways involves using Seaborn*

# %%
#your code-1st way
plt.scatter(x=titanic['Fare'], y=titanic['Age'])

# %%
# your code-2nd way
sns.scatterplot(x="Fare", y="Age", data=titanic)

# %% [markdown]
# #### Using Seaborn plot the correlation matrix of various features.
#
# *Hint: search how to use `heatmap`*

# %%
numeric.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.038354  0.025325 -0.055224  0.008942
# Survived       -0.005007  1.000000 -0.338481 -0.065376 -0.035322  0.081629
# Pclass         -0.038354 -0.338481  1.000000 -0.425965  0.060832  0.018322
# Age             0.025325 -0.065376 -0.425965  1.000000 -0.260706 -0.145488
# SibSp          -0.055224 -0.035322  0.060832 -0.260706  1.000000  0.373587
# Parch           0.008942  0.081629  0.018322 -0.145488  0.373587  1.000000
# Fare            0.031128  0.257307 -0.558683  0.171355  0.160349  0.221635
#
#                  Fare
# PassengerId  0.031128
# Survived     0.257307
# Pclass      -0.558683
# Age          0.171355
# SibSp        0.160349
# Parch        0.221635
# Fare         1.000000

# %%
#your code here
sns.heatmap(numeric.corr())

# %% [markdown]
# #### According to the previous plot, what are the most correlated feature? Comment.

# %%
#your comment here
Fare et PClass, Age et Pclass, PClass et Survived

# %% [markdown]
# #### Use the appropriate plot to display the summary statistics of the `Age` in function of the `Pclass`.
#
# *Hint: use boxplot to display summary statistics of `Age` in relation to each of the discrete values of `Pclass`*

# %%
#your code here
ax = sns.boxplot(x="Pclass", y="Age", data=titanic)
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
# Out:
# [Text(0, 0, '1'), Text(0, 0, '2'), Text(0, 0, '3')]

# %% [markdown]
# #### Use the appropriate plot to display the distributions of  `Age` in relation to  `Gender`.
#
# *Hint: use Facetgrid to display the distribution of `Age` for each categorical value of `Gender`*

# %%
#your code here
g = sns.FacetGrid(titanic, col='Gender')
g = g.map(plt.hist, 'Age', color="r")
