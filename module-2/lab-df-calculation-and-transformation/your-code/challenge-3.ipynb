# %% [markdown]
# # Challenge 3
#
# In this challenge we will work on the `Orders.csv` data set in the previous [Subsetting and Descriptive Stats lab](../../lab-subsetting-and-descriptive-stats/your-code/main.ipynb). In your work you will apply the thinking process and workflow we showed you in Challenge 2.
#
# You are serving as a Business Intelligence Analyst at the headquarter of an international fashion goods chain store. Your boss today asked you to do two things for her:
#
# **First, identify two groups of customers from the data set.** The first group is **VIP Customers** whose **aggregated expenses** at your global chain stores are **above the 95th percentile** (aka. 0.95 quantile). The second group is **Preferred Customers** whose **aggregated expenses** are **between the 75th and 95th percentile**.
#
# **Second, identify which country has the most of your VIP customers, and which country has the most of your VIP+Preferred Customers combined.**

# %% [markdown]
# # Q1: How to identify VIP & Preferred Customers?
#
# We start by importing all the required libraries:

# %%
# import required libraries
import numpy as np
import pandas as pd

# %% [markdown]
# Next, import `Orders.csv` from the "subsetting" lab folder into a dataframe variable called `orders`. Print the head of `orders` to overview the data:

# %%
# enter your code here
orders = pd.read_csv("Orders.zip", index_col=0)
orders.head()
# Out:
#    InvoiceNo StockCode  year  month  day  hour  \
# 0     536365    85123A  2010     12    3     8
# 1     536365     71053  2010     12    3     8
# 2     536365    84406B  2010     12    3     8
# 3     536365    84029G  2010     12    3     8
# 4     536365    84029E  2010     12    3     8
#
#                            Description  Quantity          InvoiceDate  \
# 0   white hanging heart t-light holder         6  2010-12-01 08:26:00
# 1                  white metal lantern         6  2010-12-01 08:26:00
# 2       cream cupid hearts coat hanger         8  2010-12-01 08:26:00
# 3  knitted union flag hot water bottle         6  2010-12-01 08:26:00
# 4       red woolly hottie white heart.         6  2010-12-01 08:26:00
#
#    UnitPrice  CustomerID         Country  amount_spent
# 0       2.55       17850  United Kingdom         15.30
# 1       3.39       17850  United Kingdom         20.34
# 2       2.75       17850  United Kingdom         22.00
# ...

# %% [markdown]
# ---
#
# "Identify VIP and Preferred Customers" is the non-technical goal of your boss. You need to translate that goal into technical languages that data analysts use:
#
# ## How to label customers whose aggregated `amount_spent` is in a given quantile range?

# %% [markdown]
# We break down the main problem into several sub problems:
#
# #### Sub Problem 1: How to aggregate the  `amount_spent` for unique customers?
#
# #### Sub Problem 2: How to select customers whose aggregated `amount_spent` is in a given quantile range?
#
# #### Sub Problem 3: How to label selected customers as "VIP" or "Preferred"?
#
# *Note: If you want to break down the main problem in a different way, please feel free to revise the sub problems above.*
#
# Now in the workspace below, tackle each of the sub problems using the iterative problem solving workflow. Insert cells as necessary to write your codes and explain your steps.

# %%
# your code here
summ = orders.groupby(orders['CustomerID']).sum()
summ['amount_spent']
summ
# Out:
#             InvoiceNo     year  month   day   hour  Quantity  UnitPrice  \
# CustomerID
# 12346          541431     2011      1     2     10     74215       1.04
# 12347       101296926   365971   1383   441   2219      2458     481.21
# 12348        16869685    62324    257   111    472      2341     178.71
# 12349        42165457   146803    803    73    657       631     605.10
# 12350         9231629    34187     34    51    272       197      65.30
# 12352        47523155   170935    552   243   1193       536    1354.11
# 12353         2215600     8044     20    16     68        20      24.30
# 12354        31952838   116638    232   232    754       530     261.22
# 12355         7181837    26143     65    13    169       240      54.65
# 12356        32183405   118649    142   185    592      1591     188.87
# 12357        75290940   263441   1441   917   2096      2708     438.67
# 12358        10785108    38209    168    52    190       248     157.21
# ...

# %%
VIP = summ[summ['amount_spent'] > summ['amount_spent'].quantile(0.95)]
Preferred = summ[(summ['amount_spent'] > summ['amount_spent'].quantile(0.75)) & (summ['amount_spent'] < summ['amount_spent'].quantile(0.95))]

# %%
Preferred.head()
# Out:
#             InvoiceNo    year  month  day  hour  Quantity  UnitPrice  \
# CustomerID
# 12347       101296926  365971   1383  441  2219      2458     481.21
# 12348        16869685   62324    257  111   472      2341     178.71
# 12349        42165457  146803    803   73   657       631     605.10
# 12352        47523155  170935    552  243  1193       536    1354.11
# 12356        32183405  118649    142  185   592      1591     188.87
#
#             amount_spent
# CustomerID
# 12347            4310.00
# 12348            1797.24
# 12349            1757.55
# 12352            2506.04
# 12356            2811.43

# %%
VIP.head()
# Out:
#             InvoiceNo     year  month   day  hour  Quantity  UnitPrice  \
# CustomerID
# 12346          541431     2011      1     2    10     74215       1.04
# 12357        75290940   263441   1441   917  2096      2708     438.67
# 12359       138190725   498728   1508   783  3136      1622    2137.86
# 12409        61157926   219199    789   499  1222      5551     389.62
# 12415       398543981  1439876   4254  2169  8061     77670    2097.08
#
#             amount_spent
# CustomerID
# 12346           77183.60
# 12357            6207.67
# 12359            6372.58
# 12409           11072.67
# 12415          124914.53

# %%
VIP_index = list(VIP.index)
orders_VIP['Tag'] = np.nan

# %%
summ.loc[VIP.index, 'Tag'] ='VIP'
summ.loc[Preferred.index, 'Tag'] = 'Preferred'
summ.head()
# Out:
#             InvoiceNo    year  month  day  hour  Quantity  UnitPrice  \
# CustomerID
# 12346          541431    2011      1    2    10     74215       1.04
# 12347       101296926  365971   1383  441  2219      2458     481.21
# 12348        16869685   62324    257  111   472      2341     178.71
# 12349        42165457  146803    803   73   657       631     605.10
# 12350         9231629   34187     34   51   272       197      65.30
#
#             amount_spent        Tag
# CustomerID
# 12346           77183.60        VIP
# 12347            4310.00  Preferred
# 12348            1797.24  Preferred
# 12349            1757.55  Preferred
# 12350             334.40        NaN

# %%
merge_table = orders.merge(summ['Tag'], left_on = 'CustomerID', right_index = True)
merge_table.head()
# Out:
#    InvoiceNo StockCode  year  month  day  hour  \
# 0     536365    85123A  2010     12    3     8
# 1     536365     71053  2010     12    3     8
# 2     536365    84406B  2010     12    3     8
# 3     536365    84029G  2010     12    3     8
# 4     536365    84029E  2010     12    3     8
#
#                            Description  Quantity          InvoiceDate  \
# 0   white hanging heart t-light holder         6  2010-12-01 08:26:00
# 1                  white metal lantern         6  2010-12-01 08:26:00
# 2       cream cupid hearts coat hanger         8  2010-12-01 08:26:00
# 3  knitted union flag hot water bottle         6  2010-12-01 08:26:00
# 4       red woolly hottie white heart.         6  2010-12-01 08:26:00
#
#    UnitPrice  CustomerID         Country  amount_spent        Tag
# 0       2.55       17850  United Kingdom         15.30  Preferred
# 1       3.39       17850  United Kingdom         20.34  Preferred
# ...

# %% [markdown]
# Now we'll leave it to you to solve Q2 & Q3, which you can leverage from your solution for Q1:
#
# # Q2: How to identify which country has the most VIP Customers?
#
# # Q3: How to identify which country has the most VIP+Preferred Customers combined?
#
# Provide your solution for Q2 below:

# %%
# your code here
VIP_country = merge_table[merge_table['Tag'] == 'VIP'].groupby(merge_table.Country).count()
VIP_country[VIP_country['CustomerID'] == VIP_country['CustomerID'].max()]
# Out:
#                 InvoiceNo  StockCode   year  month    day   hour  Description  \
# Country
# United Kingdom      84185      84185  84185  84185  84185  84185        84185
#
#                 Quantity  InvoiceDate  UnitPrice  CustomerID  Country  \
# Country
# United Kingdom     84185        84185      84185       84185    84185
#
#                 amount_spent    Tag
# Country
# United Kingdom         84185  84185

# %%
VIP_pref_country = merge_table[(merge_table['Tag'] == 'VIP') | (merge_table['Tag'] == 'Preferred')].groupby(merge_table.Country).count()
VIP_pref_country[VIP_pref_country['CustomerID'] == VIP_pref_country['CustomerID'].max()]
# Out:
#                 InvoiceNo  StockCode    year   month     day    hour  \
# Country
# United Kingdom     221635     221635  221635  221635  221635  221635
#
#                 Description  Quantity  InvoiceDate  UnitPrice  CustomerID  \
# Country
# United Kingdom       221635    221635       221635     221635      221635
#
#                 Country  amount_spent     Tag
# Country
# United Kingdom   221635        221635  221635
